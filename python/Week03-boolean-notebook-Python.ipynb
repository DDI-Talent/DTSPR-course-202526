# %% [markdown]
# # Python data types notebook - Boolean
#
# ## 0. Introduction
#
# In these notebooks, we will be looking at the data types discussed in the Week 2 & 3 content, how they work in Python, and how you can manipulate them.
#
# **Everything in Python is an object.** A data type of an object or variable specifies the type of data that is stored inside that object and how you can then interact with it. As a reminder, virtually everything in Python is an object - not just variables. As a consequence, you will be seeing a lot of the dot syntax mentioned in Week 1 in this notebook to access methods and attributes within objects of interest (methods, packages, data objects, etc.). If you wish to see the methods and attributes available for a given object, you can type the object and dot and then click TAB on your keyboard, which will then show the available list. This can be super useful to avoid typos.
#
# There are numerous notebooks this week, but they are intended to be a key reference guide for working with Python data types. *Do not* feel that you need to complete the notebooks for Week 2 and Week 3 in 1 sitting, or even 2. Feel free to make notes for yourself by inserting cells throughout the notebook as you go through, or take notes on a separate document of your choosing.
#
# **📝Note:** there is code throughout this workbook which will intentionally produce an error. Try to read the error messages and see if you can understand what is causing the problem and why. Python error messages tend to be quite helpful and specific, actually (the same cannot be said for R all of the time, so enjoy the specificity while you can!). Reading error messages and not being frightened by them is a key skill for any programmer! Review the materials from the Week 2 tutorial on reading error messages - remember, you are the detective! 🔍
#
# ✅ Remember to RUN ALL THE CELLS IN ORDER AS YOU GO THROUGH THIS NOTEBOOK (if you skip some, you might see some unexpected errors).
#
# ✅ Remember, you can use keyboard shortcuts to execute cells:
#
# - `Ctrl/Cmd + Enter` to run a cell and stay in the same cell
# - `Shift + Enter` to run a cell and go to the next cell
#
# ✅ When returning to this workbook, make sure to rerun the first code cell to load the packages and modules.
#
# ✅ To see line numbers within code cells, you can use the keyboard shortcut SHIFT-L or navigate to View > Show Line Numbers.
#
# ✅ As you go through the document, you can "fold" the code cells under a markdown cell with a header by hovering your mouse over the header name (e.g., "2. Boolean") and clicking the grey arrow that appears.

# %% [markdown]
# ## 0.1 Review of data types in Python
#
# ### Python has 5 basic data types.
# * **Boolean:** `True`, `False`
# * **numeric**
#     * integer: `-1`, `2`
#     * float:  `1.0`, `15.3`
#     * complex: `1+4j`
# * **string (character):** `“health care”`, `“social care”`
#
# ### From the `pandas` library, we can get the categorical data type
# * **category:** apple, banana, orange
#
# ### From the `datetime` module, we can get date and time datatypes
# * **date:** 2025-06-01
# * **time:** 15:30:43
# * **datetime:** 2025-06-01 15:30:43
#
# ### Python also provides functions to examine data type features, for example
# * `type()` - what is the object’s data type?
# * `len()` - how long is the data?
# * `isinstance()` - to check if an object is a given data type, returns a Boolean value
#      - this function takes 2 arguments, `isinstance(object, datatype)`. You can list multiple data types `isinstance(object, (datatype, datatype, datatype)` which is the equivalent of an "or statement" (so if one statement is true, the output will be true)
#
# ### Casting
# The process of specifying a data type on a variable is called **casting** in Python. Because Python is an OOP (object-oriented programming) language, classes are used to define data types. Therefore, casting is done using constructor functions.
#
# * `int()` - constructs an integer number from a float or string (if the string represents a whole number)
# * `float()` - constructs a float form number from an integer or string (if the string represents a float or integer)
# * `str()` - constructs a string from a wide variety of data types, including string, integer, float, etc.
# * `bool()` - constructs Boolean data types from integers or floats

# %% [markdown]
# ## 1. Boolean
#
# In Python, the bool data type is built-in, meaning it does not need to be imported and is always available. No other value besides `True` and `False` will have `bool` as its type. The class `bool` is actually a subclass of the class `int` as True and False values are represented as 1 and 0.
#
# To work with boolean data types and values, we can use relational, logical, and identity operators.

# %%
type(False)

# %%
type(True)

# %% [markdown]
# It is possible to assign a Boolean value to a variable, but it is not possible to assign a value to a Boolean value (as `True` and `False` are keywords).

# %%
a_true_variable = True 

print(a_true_variable)

# %%
type(a_true_variable)

# %%
True = 44 # this will produce an error

# %% [markdown]
# As keywords, True and False must have an upper case 1st letter

# %%
f = false # this will produce an error

# %% [markdown]
# Since `True` and `False` are equivalent to `1` and `0`, they can be cast to the respective types with `int()`, `float()`, and `complex()`

# %%
print(int(True)) 

print(int(False))

# %% [markdown]
# *📝 Note*: the code above is nested (where 1 piece of code is placed inside another). So in the example it is executed/read from the inside out, `int()` then `print()`

# %% [markdown]
# 📝🐍 A note on printing behaviour - in Jupyter Lab/Python in general, it is common to use multiple `print()` statements for any output you wish to see printed out. This is *not* the case in R/RStudio wherein there is default/auto-printing.  Without print statements in Python, if you have multiple expressions in a code cell, only the final one is printed out. See this below:

# %%
int(True)
int(False)

# %%
print(float(True))
print(float(False))

# %%
print(complex(True))
print(complex(False))

# %% [markdown]
# You can also convert `True` and `False` to strings using `str()`

# %%
print(str(True))
print(type(str(True))) 

print("") # this line creates a space divide in the code cell print out

print(str(False))
print(type(str(False)))

# %% [markdown]
# Due to the concepts of Truthy and Falsey, non-empty strings are considered `True`. So, if you convert `False` to a string and then back to a Boolean type, it will be `True` 🤯

# %%
print(bool(str(False)))

# %% [markdown]
# ### 1.1 Comparison operators
#
# Comparison operators compare the value of each operand according to the specified operator and return a boolean output:

# %%
# 1st assign values to x1 and x2 
x1 = 10 
x2 = 20

# %% [markdown]
# 📝 Note that the code cell above does not produce any print out - this is becuase we are only assigning values to objects `x1` and `x2`, there is no output as part of this code executing.

# %%
# equal to 
x1 == x2

# %%
# not equal to 
x1 != x2

# %%
# less than or equal to
x1 <= x2

# %%
# Greater than or equal to
x1 >= x2

# %% [markdown]
# ### 1.2 Identity operators
#
# `is` and `is not` are identity operators, which determine whether the given operands refer to the same object (have the same identity).
#
# You can have 2 objects that are equal in value, but not identitical (i.e.,  are not the same object, with the same memory location):

# %%
obj0 = 1001 

obj1 = 1000 + 1 

print(obj0, obj1)

# %%
print(obj0 == obj1)

# %%
print(obj0 is obj1)

# again this print statement below functions just to separate out the print out for this code cell executing 
print("-----") 

print(obj0 is not obj1)

# %% [markdown]
# As we can see both objects *equal* 1001, but they do not refer to the same object. We can confirm that they do not reference the same object with `id()`

# %%
print(id(obj0))

print(id(obj1))

# indeed obj0 and obj1 have different ids

# %% [markdown]
# ### 1.3 Logical operators
#
# Logical operators are used to combine conditional statements, with a boolean output

# %%
x1 > 5 and x2 < 25

# %%
x1 > 5 or x2 > 10

# %%
not(x1 > 5 and x2 < 25)

# %% [markdown]
# ### 1.4 Casting with Boolean data
#
# Integers and floating point numbers can be cast to boolean type data using the `bool()` function. An `int`, `float` or `complex` number set to zero returns `False`. An `int`, `float` or `complex` number set to any other number, positive or negative, returns `True`.

# %%
zero_int = 0 

bool(zero_int)

# %%
pos_int = 1

bool(pos_int)

# %%
neg_flt = -5.4

bool(neg_flt)

# %% [markdown]
# ---
#
# ## You did it! 🎉
#
# Well done for making it to the end of this notebook. If you have not done so yet, move to the R logical notebook next or move onto the Python numeric notebook.

# %% [markdown]
# ---
# *Dr. Brittany Blankinship (2026)*
